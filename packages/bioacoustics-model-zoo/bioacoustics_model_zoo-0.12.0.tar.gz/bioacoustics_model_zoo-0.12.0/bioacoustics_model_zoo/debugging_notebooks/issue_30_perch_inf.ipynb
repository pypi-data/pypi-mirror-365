# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import bioacoustics_model_zoo as bmz
import opensoundscape as opso

# %%
m = bmz.Perch()
# Out:
# /Users/SML161/miniconda3/envs/bmz_tf/lib/python3.11/site-packages/opensoundscape/ml/cnn.py:599: UserWarning:
#                     This architecture is not listed in opensoundscape.ml.cnn_architectures.ARCH_DICT.
#                     It will not be available for loading after saving the model with .save() (unless using pickle=True).
#                     To make it re-loadable, define a function that generates the architecture from arguments: (n_classes, n_channels)
#                     then use opensoundscape.ml.cnn_architectures.register_architecture() to register the generating function.
#
#                     The function can also set the returned object's .constructor_name to the registered string key in ARCH_DICT
#                     to avoid this warning and ensure it is reloaded correctly by opensoundscape.ml.load_model().
#
#                     See opensoundscape.ml.cnn_architectures module for examples of constructor functions
#
#   warnings.warn(
# ...

# %%
s = m.preprocessor.forward(("./perch_false_alarm_sliced.wav", 20))
s.data.samples.min()
# Out:
# -0.5

# %%
preds = m.predict("./perch_false_alarm_sliced.wav")
# Out:
#   0%|          | 0/12 [00:00<?, ?it/s]
# /Users/SML161/miniconda3/envs/bmz_tf/lib/python3.11/site-packages/torch/utils/data/dataloader.py:683: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# 2025-07-29 17:59:51.515948: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:38] Ignoring Assert operator jax2tf_infer_fn_/assert_equal_1/Assert/AssertGuard/Assert

# %%
preds
# Out:
#                                                       aakspa1    abbbab1  \
# file                           start_time end_time
# ./perch_false_alarm_sliced.wav 0.0        5.0      -12.918820  -8.970079
#                                5.0        10.0     -12.858785 -10.856501
#                                10.0       15.0     -12.922643  -8.700891
#                                15.0       20.0     -13.177748 -10.516693
#                                20.0       25.0     -13.079013  -9.329353
#                                25.0       30.0     -12.875122  -9.497975
#                                30.0       35.0     -12.761959 -10.228333
#                                35.0       40.0     -12.755678 -10.191586
#                                40.0       45.0     -12.740712  -9.753169
#                                45.0       50.0     -12.333328 -10.979345
#                                50.0       55.0     -12.788630  -9.012329
# ...
