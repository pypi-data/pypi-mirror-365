# %%
import bioacoustics_model_zoo as bmz
import opensoundscape as opso

# %%
m = bmz.BirdNET()
# Out:
# File BirdNET_GLOBAL_6K_V2.4_Labels_af.txt found in cache at /Users/SML161/Library/Caches/bioacoustics_model_zoo/birdnet/2.4/BirdNET_GLOBAL_6K_V2.4_Labels_af.txt
# downloading model from URL...
# File BirdNET_GLOBAL_6K_V2.4_Model_FP16.tflite found in cache at /Users/SML161/Library/Caches/bioacoustics_model_zoo/birdnet/2.4/BirdNET_GLOBAL_6K_V2.4_Model_FP16.tflite
# /Users/SML161/miniconda3/envs/bmz_dev/lib/python3.12/site-packages/opensoundscape/ml/cnn.py:599: UserWarning:
#                     This architecture is not listed in opensoundscape.ml.cnn_architectures.ARCH_DICT.
#                     It will not be available for loading after saving the model with .save() (unless using pickle=True).
#                     To make it re-loadable, define a function that generates the architecture from arguments: (n_classes, n_channels)
#                     then use opensoundscape.ml.cnn_architectures.register_architecture() to register the generating function.
#
# ...

# %%
m.predict(opso.birds_path)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# /Users/SML161/miniconda3/envs/bmz_dev/lib/python3.12/site-packages/torch/utils/data/dataloader.py:683: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
#                                                                         Abroscopus albogularis_Rufous-faced Warbler  \
# file                                               start_time end_time
# /Users/SML161/miniconda3/envs/bmz_dev/lib/pytho... 0.0        3.0                                        -10.638823
#                                                    3.0        6.0                                        -11.993023
#                                                    6.0        9.0                                         -9.344634
#
#                                                                         Abroscopus schisticeps_Black-faced Warbler  \
# ...
