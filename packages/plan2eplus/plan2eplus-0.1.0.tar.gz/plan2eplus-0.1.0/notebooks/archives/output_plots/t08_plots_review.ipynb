# %%
import sys
sys.path.append("/Users/julietnwagwuume-ezeoke/_UILCode/gqe-phd/geomeppy/_scripts")


from case_edits.recipes.two_zone import ezcase as ez
from datetime import time
# Out:
# Added 5 walls
# Added 4 walls
# `AFN Zone Ventilation Air Change Rate` is already in IDF
# cases/tests/test16_ezcase/out.idf

# %%
ez.plotter.plot_surface_over_time(ez.outputs.surf_net_thermal_rad7_21)
# Out:
# No data for Block 01 - North - W02_1
# No data for Block 00 - South - W04_1

# %%
ez.plotter.plot_zone_over_time(ez.outputs.zone_mean_air_temp7_21)

# %%
ez.plotter.plot_zone_at_different_time_2d(ez.outputs.zone_mean_air_temp7_21, [time(6), time(12), time(18)])
