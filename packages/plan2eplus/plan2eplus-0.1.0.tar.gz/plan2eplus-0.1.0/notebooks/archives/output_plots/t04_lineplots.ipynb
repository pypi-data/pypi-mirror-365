# %%
import sys
sys.path.append("/Users/julietnwagwuume-ezeoke/_UILCode/gqe-phd/geomeppy/_scripts")

from outputs.sql import SQLReader
from outputs.time import TimePlot

import plotly.graph_objects as go

# %%
sql = TimePlot("test03")

# %%
sql.epcase.idf.idfobjects["SITE:LOCATION"]
# Out:
# [
# Site:Location,
#     DENVER_STAPLETON_CO_USA_WMO_724690,    !- Name
#     39.77,                    !- Latitude
#     -104.87,                  !- Longitude
#     -7,                       !- Time Zone
#     1611;                     !- Elevation
# ]

# %%
sql.dataset_names
# Out:
# ['zone_mean_air_temp12-21', 'zone_mean_air_temp7-21']

# %%
sql.make_time_plot(sql.dataset_names[0])

# %%
sql.make_time_plot(sql.dataset_names[1])
